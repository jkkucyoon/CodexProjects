# %% [markdown]
# # Exploration Notebook
#
# This notebook is a starter for EDA on the Kaggle *Company Bankruptcy Prediction* dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/company_bankruptcy.csv')
df.head()

# %%
df['Bankrupt?'].value_counts(normalize=True).plot(kind='bar', title='Target Distribution')
plt.show()
